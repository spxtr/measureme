# %%
import sweep
import numpy as np
from qcodes.tests.instrument_mocks import DummyInstrument, DummyInstrumentWithMeasurement

# %%
dac = DummyInstrument(name="dac", gates=['ch1', 'ch2', 'ch3', 'ch4'])
dmm = DummyInstrumentWithMeasurement(name="dmm", setter_instr=dac)

# %%
sweep.set_basedir('../measureme_testdata')

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)

# %%
s.reset()

# %%
result = s.measure()
# Out:
# 2023-11-14 15:07:31,478 [INFO] Starting measure with ID 168
# 2023-11-14 15:07:31,493 [INFO] Data saved in ../measureme_testdata\168\data.tsv.gz

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)
result = s.measure()
# Out:
# 2023-11-14 15:07:31,498 [INFO] Starting measure with ID 169
# 2023-11-14 15:07:31,513 [INFO] Data saved in ../measureme_testdata\169\data.tsv.gz

# %%
np.random.choice(10)
# Out:
# 0

# %%
result = s.watch(max_duration=1)
# Out:
# 2023-11-14 15:07:31,529 [INFO] Starting watch with ID 170
# 2023-11-14 15:07:32,727 [INFO] Completed in 0h 0m 0s
# 2023-11-14 15:07:32,727 [INFO] Data saved in ../measureme_testdata\170\data.tsv.gz

# %%
result = s.sweep(dac.ch1, [0, 0.1, 0.2, 0.3], delay=0.1)
# Out:
# 2023-11-14 15:07:32,733 [INFO] Starting sweep with ID 171
# 2023-11-14 15:07:32,734 [INFO] Minimum duration 0h 0m 0s
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2023-11-14 15:07:33,717 [INFO] Completed in 0h 0m 0s
# 2023-11-14 15:07:33,718 [INFO] Data saved in ../measureme_testdata\171\data.tsv.gz

# %%
result = s.multisweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], delay=0.1)
# Out:
# 2023-11-14 15:07:33,724 [INFO] Starting multisweep with ID 172
# 2023-11-14 15:07:33,725 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-14 15:07:35,042 [INFO] Completed in 0h 0m 1s
# 2023-11-14 15:07:35,042 [INFO] Data saved in ../measureme_testdata\172\data.tsv.gz

# %%
result = s.megasweep(dac.ch1, np.linspace(0, 10, 11), dac.ch2, np.linspace(0, 10, 11), fast_delay=0.01)
# Out:
# 2023-11-14 15:07:35,050 [INFO] Starting megasweep with ID 173
# 2023-11-14 15:07:35,050 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-14 15:07:36,954 [INFO] Completed in 0h 0m 1s
# 2023-11-14 15:07:36,954 [INFO] Data saved in ../measureme_testdata\173\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1, init_delay=False)
# Out:
# 2023-11-14 15:07:36,961 [INFO] Starting multimegasweep with ID 174
# 2023-11-14 15:07:36,961 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-14 15:07:39,764 [INFO] Completed in 0h 0m 2s
# 2023-11-14 15:07:39,765 [INFO] Data saved in ../measureme_testdata\174\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=1, slow_delay=1)
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
# Out:
# 2023-11-14 15:07:39,772 [INFO] Starting multimegasweep with ID 175
# 2023-11-14 15:07:39,773 [INFO] Minimum duration 0h 2m 12s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
dac.ch1(0.5)

# %%
dac.ch1()

# %%
s.ramp(dac.ch1, 0.5)

# %%
s.read(dac.ch1)

# %%
s.read_all()
