# %%
import sweep
from sweep import sweep_load as sl
import numpy as np
from qcodes.tests.instrument_mocks import DummyInstrument, DummyInstrumentWithMeasurement

# %%
dac = DummyInstrument(name="dac", gates=['ch1', 'ch2', 'ch3', 'ch4'])
dmm = DummyInstrumentWithMeasurement(name="dmm", setter_instr=dac)

# %%
data_dir = r'..\measureme_testdata'
sweep.set_basedir(data_dir)

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)

# %%
s.reset()

# %%
result = s.measure()
# Out:
# 2023-12-22 12:39:01,146 [INFO] Starting measure with ID 21
# 2023-12-22 12:39:01,197 [INFO] Data saved in ..\measureme_testdata\21\data.tsv.gz

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)
result = s.measure()
# Out:
# 2023-12-22 12:39:01,408 [INFO] Starting measure with ID 22
# 2023-12-22 12:39:01,455 [INFO] Data saved in ..\measureme_testdata\22\data.tsv.gz

# %%
np.random.choice(10)
# Out:
# 8

# %%
result = s.watch(max_duration=1)
# Out:
# 2023-12-22 12:39:01,858 [INFO] Starting watch with ID 23
# 2023-12-22 12:39:05,249 [INFO] Completed in 0h 0m 2s
# 2023-12-22 12:39:05,251 [INFO] Data saved in ..\measureme_testdata\23\data.tsv.gz

# %%
result = s.sweep(dac.ch1, [0, 0.1, 0.2, 0.3], delay=0.1)
# Out:
# 2023-12-22 12:39:05,344 [INFO] Starting sweep with ID 24
# 2023-12-22 12:39:05,346 [INFO] Minimum duration 0h 0m 0s
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2023-12-22 12:39:08,810 [INFO] Completed in 0h 0m 0s
# 2023-12-22 12:39:08,811 [INFO] Data saved in ..\measureme_testdata\24\data.tsv.gz

# %%
result = s.multisweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], delay=0.1)
# Out:
# 2023-12-22 12:39:08,903 [INFO] Starting multisweep with ID 25
# 2023-12-22 12:39:08,907 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:39:12,444 [INFO] Completed in 0h 0m 1s
# 2023-12-22 12:39:12,445 [INFO] Data saved in ..\measureme_testdata\25\data.tsv.gz

# %%
result = s.megasweep(dac.ch1, np.linspace(0, 10, 11), dac.ch2, np.linspace(0, 10, 11), fast_delay=0.01)
# Out:
# 2023-12-22 12:39:12,563 [INFO] Starting megasweep with ID 26
# 2023-12-22 12:39:12,566 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:39:17,531 [INFO] Completed in 0h 0m 4s
# 2023-12-22 12:39:17,532 [INFO] Data saved in ..\measureme_testdata\26\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1, init_delay=False)
# Out:
# 2023-12-22 12:39:17,632 [INFO] Starting multimegasweep with ID 27
# 2023-12-22 12:39:17,634 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:39:23,331 [INFO] Completed in 0h 0m 4s
# 2023-12-22 12:39:23,332 [INFO] Data saved in ..\measureme_testdata\27\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
# Out:
# 2023-12-22 12:39:23,442 [INFO] Starting multimegasweep with ID 28
# 2023-12-22 12:39:23,444 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:39:29,553 [INFO] Completed in 0h 0m 5s
# 2023-12-22 12:39:29,554 [INFO] Data saved in ..\measureme_testdata\28\data.tsv.gz
# 2023-12-22 12:39:29,582 [INFO] Starting multimegasweep with ID 29
# 2023-12-22 12:39:29,584 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:39:35,225 [INFO] Completed in 0h 0m 4s
# 2023-12-22 12:39:35,226 [INFO] Data saved in ..\measureme_testdata\29\data.tsv.gz

# %% [markdown]
# # Testing some basic logging functionality

# %%
s.ramp(dac.ch1, 2.2)
# Out:
# 2023-12-22 12:39:35,289 [INFO] Ramping dac_ch1: 10.0 -> 2.2

# %%
s.read(dac.ch1)
# Out:
# 2023-12-22 12:39:35,475 [INFO] Reading dac_ch1: 2.2

# %%
s.read_all()
# Out:
# 2023-12-22 12:39:35,827 [INFO] Reading all parameters:
# 2023-12-22 12:39:35,829 [INFO] Reading dmm_v1: 3.277508730033219
# 2023-12-22 12:39:35,830 [INFO] Reading dmm_v2: 4.128792448044782e-06

# %% [markdown]
# # Testing loading

# %%
sl.load_meta(data_dir, 3)
# Out:
# {'comments': [],
#  'type': '0D',
#  'columns': ['time', 'dmm_v1', 'dmm_v2'],
#  'time': 1703276650.6186142}

# %%
data = sl.pload0d(data_dir, 3)
print(data.keys())

# %%
data = sl.pload1d(data_dir, 5)
print(data.keys())
# Out:
# dict_keys(['time', 'dmm_v1', 'dmm_v2'])
