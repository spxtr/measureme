# %%
import sweep
import numpy as np
from qcodes.tests.instrument_mocks import DummyInstrument, DummyInstrumentWithMeasurement

# %%
dac = DummyInstrument(name="dac", gates=['ch1', 'ch2', 'ch3', 'ch4'])
dmm = DummyInstrumentWithMeasurement(name="dmm", setter_instr=dac)

# %%
sweep.set_basedir('../measureme_testdata')

# %%
s = sweep.Station(verbose=True)
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)

# %%
s.reset()

# %%
result = s.measure()
# Out:
# 2023-11-11 18:56:40,024 [INFO] Starting measure with ID 58
# 2023-11-11 18:56:40,040 [INFO] Data saved in ../measureme_testdata\58\data.tsv.gz

# %%
result = s.watch(max_duration=1)
# Out:
# 2023-11-11 18:56:40,048 [INFO] Starting watch with ID 59
# 2023-11-11 18:56:41,214 [INFO] Completed in 0h 0m 1s
# 2023-11-11 18:56:41,214 [INFO] Data saved in ../measureme_testdata\59\data.tsv.gz

# %%
result = s.sweep(dac.ch1, [0, 0.1, 0.2, 0.3], delay=0.1)
# Out:
# 2023-11-11 18:56:41,218 [INFO] Starting sweep with ID 60
# 2023-11-11 18:56:41,219 [INFO] Minimum duration 0h 0m 0s
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2023-11-11 18:56:42,133 [INFO] Completed in 0h 0m 0s
# 2023-11-11 18:56:42,134 [INFO] Data saved in ../measureme_testdata\60\data.tsv.gz

# %%
result = s.multisweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], delay=0.1)
# Out:
# 2023-11-11 18:56:42,139 [INFO] Starting multisweep with ID 61
# 2023-11-11 18:56:42,139 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-11 18:56:43,444 [INFO] Completed in 0h 0m 1s
# 2023-11-11 18:56:43,444 [INFO] Data saved in ../measureme_testdata\61\data.tsv.gz

# %%
result = s.megasweep(dac.ch1, np.linspace(0, 10, 11), dac.ch2, np.linspace(0, 10, 11), fast_delay=0.01)
# Out:
# 2023-11-11 18:56:43,449 [INFO] Starting megasweep with ID 62
# 2023-11-11 18:56:43,450 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-11 18:56:45,303 [INFO] Completed in 0h 0m 1s
# 2023-11-11 18:56:45,304 [INFO] Data saved in ../measureme_testdata\62\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1, init_delay=False)
# Out:
# 2023-11-11 18:56:45,310 [INFO] Starting multimegasweep with ID 63
# 2023-11-11 18:56:45,310 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-11 18:56:48,061 [INFO] Completed in 0h 0m 2s
# 2023-11-11 18:56:48,061 [INFO] Data saved in ../measureme_testdata\63\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
# Out:
# 2023-11-11 18:56:48,067 [INFO] Starting multimegasweep with ID 64
# 2023-11-11 18:56:48,067 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-11 18:56:50,821 [INFO] Completed in 0h 0m 2s
# 2023-11-11 18:56:50,822 [INFO] Data saved in ../measureme_testdata\64\data.tsv.gz
# 2023-11-11 18:56:50,824 [INFO] Starting multimegasweep with ID 65
# 2023-11-11 18:56:50,825 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-11 18:56:53,570 [INFO] Completed in 0h 0m 2s
# 2023-11-11 18:56:53,571 [INFO] Data saved in ../measureme_testdata\65\data.tsv.gz

# %%
s.ramp(dac.ch1, 0.5)
# Out:
# 2023-11-11 18:56:53,574 [INFO] Ramping dac_ch1: 0.5

# %%
s.read(dac.ch1)
# Out:
# 2023-11-11 19:01:47,215 [INFO] Reading dac_ch1: 0.5

# %%
s.read_all()
# Out:
# 2023-11-11 18:56:53,586 [INFO] Reading all parameters:
# 2023-11-11 18:56:53,587 [INFO] Reading dmm_v1: 4.581861578760461
# 2023-11-11 18:56:53,587 [INFO] Reading dmm_v2: -0.0011415548464068959
