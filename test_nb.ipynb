# %%
import sweep
from sweep import sweep_load as sl
from sweep import raster

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from qcodes.tests.instrument_mocks import DummyInstrument, DummyInstrumentWithMeasurement

# %%
dac = DummyInstrument(name="dac", gates=['ch1', 'ch2', 'ch3', 'ch4'])
dmm = DummyInstrumentWithMeasurement(name="dmm", setter_instr=dac)

# %%
data_dir = r'..\measureme_testdata'
sweep.set_basedir(data_dir)

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)

# %%
s.reset()

# %%
result = s.measure()
# Out:
# 2023-12-22 13:06:01,133 [INFO] Starting measure with ID 41
# 2023-12-22 13:06:01,191 [INFO] Data saved in ..\measureme_testdata\41\data.tsv.gz

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)
result = s.measure()
# Out:
# 2023-12-22 13:06:01,259 [INFO] Starting measure with ID 42
# 2023-12-22 13:06:01,296 [INFO] Data saved in ..\measureme_testdata\42\data.tsv.gz

# %%
np.random.choice(10)
# Out:
# 6

# %%
result = s.watch(max_duration=1)
# Out:
# 2023-12-22 13:06:01,429 [INFO] Starting watch with ID 43
# 2023-12-22 13:06:06,233 [INFO] Completed in 0h 0m 3s
# 2023-12-22 13:06:06,234 [INFO] Data saved in ..\measureme_testdata\43\data.tsv.gz

# %%
result = s.sweep(dac.ch1, [0, 0.1, 0.2, 0.3], delay=0.1)
# Out:
# 2023-12-22 13:06:06,295 [INFO] Starting sweep with ID 44
# 2023-12-22 13:06:06,297 [INFO] Minimum duration 0h 0m 0s
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2023-12-22 13:06:09,958 [INFO] Completed in 0h 0m 0s
# 2023-12-22 13:06:09,959 [INFO] Data saved in ..\measureme_testdata\44\data.tsv.gz

# %%
result = s.multisweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], delay=0.1)
# Out:
# 2023-12-22 13:06:10,010 [INFO] Starting multisweep with ID 45
# 2023-12-22 13:06:10,012 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 13:06:14,117 [INFO] Completed in 0h 0m 1s
# 2023-12-22 13:06:14,119 [INFO] Data saved in ..\measureme_testdata\45\data.tsv.gz

# %%
result = s.megasweep(dac.ch1, np.linspace(0, 10, 11), dac.ch2, np.linspace(0, 10, 11), fast_delay=0.01)
# Out:
# 2023-12-22 13:06:14,174 [INFO] Starting megasweep with ID 46
# 2023-12-22 13:06:14,176 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 13:06:22,119 [INFO] Completed in 0h 0m 6s
# 2023-12-22 13:06:22,120 [INFO] Data saved in ..\measureme_testdata\46\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1, init_delay=False)
# Out:
# 2023-12-22 13:06:22,375 [INFO] Starting multimegasweep with ID 47
# 2023-12-22 13:06:22,377 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 13:06:28,135 [INFO] Completed in 0h 0m 5s
# 2023-12-22 13:06:28,137 [INFO] Data saved in ..\measureme_testdata\47\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
# Out:
# 2023-12-22 13:06:28,214 [INFO] Starting multimegasweep with ID 48
# 2023-12-22 13:06:28,216 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 13:06:34,058 [INFO] Completed in 0h 0m 4s
# 2023-12-22 13:06:34,067 [INFO] Data saved in ..\measureme_testdata\48\data.tsv.gz
# 2023-12-22 13:06:34,119 [INFO] Starting multimegasweep with ID 49
# 2023-12-22 13:06:34,120 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 13:06:41,504 [INFO] Completed in 0h 0m 6s
# 2023-12-22 13:06:41,508 [INFO] Data saved in ..\measureme_testdata\49\data.tsv.gz

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

result = s.megasweep(dac.ch1, np.linspace(0, 10, 11), dac.ch2, np.linspace(0, 10, 11), fast_delay=0.1, slow_delay=1, init_delay=True)
# Out:
# 2023-12-22 13:24:23,825 [INFO] Starting megasweep with ID 54
# 2023-12-22 13:24:23,828 [INFO] Minimum duration 0h 0m 23s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 13:24:47,669 [INFO] Completed in 0h 0m 23s
# 2023-12-22 13:24:47,674 [INFO] Data saved in ..\measureme_testdata\54\data.tsv.gz

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)


result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1, init_delay=False)

# %% [markdown]
# # Testing some basic logging functionality

# %%
s.ramp(dac.ch1, 2.2)
# Out:
# 2023-12-22 13:06:41,774 [INFO] Ramping dac_ch1: 10.0 -> 2.2

# %%
s.read(dac.ch1)
# Out:
# 2023-12-22 13:06:42,109 [INFO] Reading dac_ch1: 2.2

# %%
s.read_all()
# Out:
# 2023-12-22 13:06:42,314 [INFO] Reading all parameters:
# 2023-12-22 13:06:42,317 [INFO] Reading dmm_v1: 3.235582521612406
# 2023-12-22 13:06:42,322 [INFO] Reading dmm_v2: 0.0007171385462104693

# %% [markdown]
# # Testing loading

# %%
sl.load_meta(data_dir, 3)
# Out:
# {'comments': [],
#  'type': '0D',
#  'columns': ['time', 'dmm_v1', 'dmm_v2'],
#  'time': 1703276650.6186142}

# %%
data = sl.pload0d(data_dir, 3)
print(data.keys(), data['dmm_v1'])
# Out:
# dict_keys(['time', 'dmm_v1', 'dmm_v2']) 5.063816767374964

# %%
data = sl.pload1d(data_dir, 5)
print(data.keys())
# Out:
# dict_keys(['time', 'dmm_v1', 'dmm_v2'])

# %% [markdown]
# # Test raster

# %%
def plot_rasterized(vertices, nx, ny, fast_axis, rev_x=False, rev_y=False):
    '''
    Plots the polygon defined by vertices and the points inside the polygon
    defined by nx and ny points along the x and y axes, respectively.
    '''

    xs, ys = raster.rasterize(vertices, nx, ny, fast_axis, rev_x, rev_y)
    
    return xs, ys

# %%
vertices = raster.random_ngon_vertices(6)
print(vertices)
xs, ys, = raster.rasterize(vertices, 101, 101, 1, rev_x=True, rev_y=False)
plt.figure()
plt.plot(vertices[:, 0], vertices[:, 1], 'k-')
plt.plot([vertices[0, 0], vertices[-1, 0]], [vertices[0, 1], vertices[-1, 1]], 'k-')
plt.scatter(xs, ys, c=np.linspace(0, 1, len(xs)), s=2, cmap='viridis')
plt.show()

# testing pcolormeshify
zs = np.random.rand(len(xs))
xs_mat, ys_mat, zs_mat = raster.pcolorize_data(zs, vertices, 101, 101, 1, rev_x=True, rev_y=False)

plt.figure()
plt.pcolormesh(xs_mat, ys_mat, zs_mat)
plt.show()
# Out:
# [[-0.11773753  5.50407981]
#  [-4.39537401 -5.39684727]
#  [-3.32731071 -5.46484828]
#  [-3.11805382 -9.36714419]
#  [ 1.18935309 -1.52242079]
#  [ 5.32091571 -3.54398357]]

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)
result = s.multisweep([dac.ch1, dac.ch2], [xs, ys], delay=0.01)
# Out:
# 2023-12-22 13:06:44,936 [INFO] Starting multisweep with ID 50
# 2023-12-22 13:06:44,939 [INFO] Minimum duration 0h 0m 32s
#   0%|          | 0/3238 [00:00<?, ?it/s]
# 2023-12-22 13:07:21,896 [INFO] Completed in 0h 0m 36s
# 2023-12-22 13:07:21,897 [INFO] Data saved in ..\measureme_testdata\50\data.tsv.gz

# %%
data = sl.pload1d(data_dir, 50)
xs = data['xs'][0]
ys = data['xs'][1]
zs1 = data['dmm_v1']
zs2 = data['dmm_v2']

xs_mat, ys_mat, zs1_mat = raster.pcolorize_data(zs1, vertices, 101, 101, 1, rev_x=True, rev_y=False)

plt.figure()
plt.pcolormesh(xs_mat, ys_mat, zs1_mat)
plt.show()

xs_mat, ys_mat, zs2_mat = raster.pcolorize_data(zs2, vertices, 101, 101, 1, rev_x=True, rev_y=False)

plt.figure()
plt.pcolormesh(xs_mat, ys_mat, zs2_mat)
plt.show()
