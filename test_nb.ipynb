# %%
import sweep
from sweep import sweep_load as sl
import numpy as np
from qcodes.tests.instrument_mocks import DummyInstrument, DummyInstrumentWithMeasurement

# %%
dac = DummyInstrument(name="dac", gates=['ch1', 'ch2', 'ch3', 'ch4'])
dmm = DummyInstrumentWithMeasurement(name="dmm", setter_instr=dac)

# %%
data_dir = r'..\measureme_testdata'
sweep.set_basedir(data_dir)

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)

# %%
s.reset()

# %%
result = s.measure()
# Out:
# 2023-12-22 12:24:10,616 [INFO] Starting measure with ID 3
# 2023-12-22 12:24:10,669 [INFO] Data saved in ..\measureme_testdata\3\data.tsv.gz

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)
result = s.measure()
# Out:
# 2023-12-22 12:24:10,697 [INFO] Starting measure with ID 4
# 2023-12-22 12:24:10,728 [INFO] Data saved in ..\measureme_testdata\4\data.tsv.gz

# %%
np.random.choice(10)
# Out:
# 3

# %%
result = s.watch(max_duration=1)
# Out:
# 2023-12-22 12:24:10,847 [INFO] Starting watch with ID 5
# 2023-12-22 12:24:18,843 [INFO] Completed in 0h 0m 5s
# 2023-12-22 12:24:18,845 [INFO] Data saved in ..\measureme_testdata\5\data.tsv.gz

# %%
result = s.sweep(dac.ch1, [0, 0.1, 0.2, 0.3], delay=0.1)
# Out:
# 2023-12-22 12:24:18,897 [INFO] Starting sweep with ID 6
# 2023-12-22 12:24:18,899 [INFO] Minimum duration 0h 0m 0s
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2023-12-22 12:24:23,728 [INFO] Completed in 0h 0m 0s
# 2023-12-22 12:24:23,730 [INFO] Data saved in ..\measureme_testdata\6\data.tsv.gz

# %%
result = s.multisweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], delay=0.1)
# Out:
# 2023-12-22 12:24:23,838 [INFO] Starting multisweep with ID 7
# 2023-12-22 12:24:23,840 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:24:28,243 [INFO] Completed in 0h 0m 1s
# 2023-12-22 12:24:28,245 [INFO] Data saved in ..\measureme_testdata\7\data.tsv.gz

# %%
result = s.megasweep(dac.ch1, np.linspace(0, 10, 11), dac.ch2, np.linspace(0, 10, 11), fast_delay=0.01)
# Out:
# 2023-12-22 12:24:28,362 [INFO] Starting megasweep with ID 8
# 2023-12-22 12:24:28,364 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:24:34,105 [INFO] Completed in 0h 0m 4s
# 2023-12-22 12:24:34,106 [INFO] Data saved in ..\measureme_testdata\8\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1, init_delay=False)
# Out:
# 2023-12-22 12:24:34,221 [INFO] Starting multimegasweep with ID 9
# 2023-12-22 12:24:34,225 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:24:40,696 [INFO] Completed in 0h 0m 5s
# 2023-12-22 12:24:40,697 [INFO] Data saved in ..\measureme_testdata\9\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
# Out:
# 2023-12-22 12:24:40,908 [INFO] Starting multimegasweep with ID 10
# 2023-12-22 12:24:40,910 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:24:48,875 [INFO] Completed in 0h 0m 6s
# 2023-12-22 12:24:48,877 [INFO] Data saved in ..\measureme_testdata\10\data.tsv.gz
# 2023-12-22 12:24:48,899 [INFO] Starting multimegasweep with ID 11
# 2023-12-22 12:24:48,901 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-12-22 12:24:56,703 [INFO] Completed in 0h 0m 6s
# 2023-12-22 12:24:56,705 [INFO] Data saved in ..\measureme_testdata\11\data.tsv.gz

# %% [markdown]
# # Testing some basic logging functionality

# %%
s.ramp(dac.ch1, 2.2)
# Out:
# 2023-12-22 12:24:57,205 [INFO] Ramping dac_ch1: 0.5 -> 2.2

# %%
s.read(dac.ch1)
# Out:
# 2023-12-22 12:24:57,398 [INFO] Reading dac_ch1: 2.2

# %%
s.read_all()
# Out:
# 2023-12-22 12:24:57,515 [INFO] Reading all parameters:
# 2023-12-22 12:24:57,519 [INFO] Reading dmm_v1: 3.3191610607502264
# 2023-12-22 12:24:57,524 [INFO] Reading dmm_v2: 0.0002272787269494606

# %% [markdown]
# # Testing loading

# %%
data = sl.pload1d(data_dir, 1)
print(data.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sl.pload1d(data_dir, 1)
#
# NameError: name 'data_dir' is not defined
