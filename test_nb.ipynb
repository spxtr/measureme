# %%
import sweep
import numpy as np
from qcodes.tests.instrument_mocks import DummyInstrument, DummyInstrumentWithMeasurement

# %%
dac = DummyInstrument(name="dac", gates=['ch1', 'ch2', 'ch3', 'ch4'])
dmm = DummyInstrumentWithMeasurement(name="dmm", setter_instr=dac)

# %%
sweep.set_basedir(r'..\measureme_testdata')

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)

# %%
s.reset()

# %%
result = s.measure()
# Out:
# 2023-11-14 15:22:52,576 [INFO] Starting measure with ID 195
# 2023-11-14 15:22:52,591 [INFO] Data saved in ..\measureme_testdata\195\data.tsv.gz

# %%
s = sweep.Station()
s.fp(dmm.v1)
s.fp(dmm.v2)

s.plot(dac.ch1, dmm.v1)
s.plot(dac.ch1, dmm.v2)
result = s.measure()
# Out:
# 2023-11-14 15:22:52,597 [INFO] Starting measure with ID 196
# 2023-11-14 15:22:52,612 [INFO] Data saved in ..\measureme_testdata\196\data.tsv.gz

# %%
np.random.choice(10)
# Out:
# 0

# %%
result = s.watch(max_duration=1)
# Out:
# 2023-11-14 15:22:52,628 [INFO] Starting watch with ID 197
# 2023-11-14 15:22:53,822 [INFO] Completed in 0h 0m 0s
# 2023-11-14 15:22:53,822 [INFO] Data saved in ..\measureme_testdata\197\data.tsv.gz

# %%
result = s.sweep(dac.ch1, [0, 0.1, 0.2, 0.3], delay=0.1)
# Out:
# 2023-11-14 15:22:53,828 [INFO] Starting sweep with ID 198
# 2023-11-14 15:22:53,829 [INFO] Minimum duration 0h 0m 0s
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2023-11-14 15:22:54,817 [INFO] Completed in 0h 0m 0s
# 2023-11-14 15:22:54,818 [INFO] Data saved in ..\measureme_testdata\198\data.tsv.gz

# %%
result = s.multisweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], delay=0.1)
# Out:
# 2023-11-14 15:22:54,825 [INFO] Starting multisweep with ID 199
# 2023-11-14 15:22:54,825 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-14 15:22:56,140 [INFO] Completed in 0h 0m 1s
# 2023-11-14 15:22:56,140 [INFO] Data saved in ..\measureme_testdata\199\data.tsv.gz

# %%
result = s.megasweep(dac.ch1, np.linspace(0, 10, 11), dac.ch2, np.linspace(0, 10, 11), fast_delay=0.01)
# Out:
# 2023-11-14 15:22:56,146 [INFO] Starting megasweep with ID 200
# 2023-11-14 15:22:56,147 [INFO] Minimum duration 0h 0m 1s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-14 15:22:58,065 [INFO] Completed in 0h 0m 1s
# 2023-11-14 15:22:58,066 [INFO] Data saved in ..\measureme_testdata\200\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1, init_delay=False)
# Out:
# 2023-11-14 15:22:58,073 [INFO] Starting multimegasweep with ID 201
# 2023-11-14 15:22:58,073 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-14 15:23:00,856 [INFO] Completed in 0h 0m 2s
# 2023-11-14 15:23:00,857 [INFO] Data saved in ..\measureme_testdata\201\data.tsv.gz

# %%
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
result = s.multimegasweep([dac.ch1, dac.ch2], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], [dac.ch3, dac.ch4], [np.linspace(0, 10, 11), np.linspace(0, 10, 11)], fast_delay=0.01, slow_delay=0.1)
# Out:
# 2023-11-14 15:23:00,865 [INFO] Starting multimegasweep with ID 202
# 2023-11-14 15:23:00,865 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-14 15:23:03,632 [INFO] Completed in 0h 0m 2s
# 2023-11-14 15:23:03,633 [INFO] Data saved in ..\measureme_testdata\202\data.tsv.gz
# 2023-11-14 15:23:03,636 [INFO] Starting multimegasweep with ID 203
# 2023-11-14 15:23:03,637 [INFO] Minimum duration 0h 0m 2s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-11-14 15:23:06,409 [INFO] Completed in 0h 0m 2s
# 2023-11-14 15:23:06,409 [INFO] Data saved in ..\measureme_testdata\203\data.tsv.gz

# %%
dac.ch1(0.5)

# %%
dac.ch1()
# Out:
# 0.5

# %%
s.ramp(dac.ch1, 2.2)
# Out:
# 2023-11-14 15:23:06,425 [INFO] Ramping dac_ch1: 0.5 -> 2.2

# %%
s.read(dac.ch1)
# Out:
# 2023-11-14 15:23:06,431 [INFO] Reading dac_ch1: 2.2

# %%
s.read_all()
# Out:
# 2023-11-14 15:23:06,437 [INFO] Reading all parameters:
# 2023-11-14 15:23:06,438 [INFO] Reading dmm_v1: 3.226447068862863
# 2023-11-14 15:23:06,438 [INFO] Reading dmm_v2: 0.00016587392311308107
